# %%
import difflib
from difflib import SequenceMatcher
import os
import pandas as pd
import csv

import re

# %%
"""
Here we create a similarty function that returns a similarity percentage of two words, the first being
one of the words from our word_list and the second being the OCR scanned word
"""

def similar(a, b):
    return SequenceMatcher(None, a.lower(), b.lower())


word_list = ['revenue', "expenditure", "balance"]

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio() * 100

def find_sequence_with_pandas(file_path):
    df = pd.read_csv(file_path, header=None)
    
    filtered_df = df[df.iloc[:, 8] < 560]
    y = df.loc[1,:].values[0]
    t = df.loc[1,:].values[1]
    
    yes_contracts_seq = ['revenue', "expenditure", "balance"]
    page_words = {}
    
    for index, row in filtered_df.iterrows():
        word = row[12].lower()
        word = re.sub(r'[^\w\s]', '', word)  # removes non-alphanumeric characters
        page = row[2]
        
        # Check similarity with each target word and add if similarity is over 70%
        for target_word in yes_contracts_seq:
            if similar(word, target_word) > 70:
                if page not in page_words:
                    page_words[page] = set()
                page_words[page].add(target_word)

                # Check if all words have been found on the same page
                if len(page_words[page]) == len(yes_contracts_seq):
                    year = row[0]
                    tif_district = row[1]
                    return f'{year}*{tif_district}*{page + 1}'
    
    
    
    
    
    
    
    maybe_contracts_seq = ['fund', "balance", "beginning", "of", "year"]
    maybe_contracts_index = 0

    for index, row in df.iterrows():
        word = row[12].lower()
        word = re.sub(r'[^\w\s]', '', word)  # removes non-alphanumeric characters
        page = row[2]

        if word == maybe_contracts_seq[maybe_contracts_index]:
            maybe_contracts_index += 1  

            if maybe_contracts_index == len(maybe_contracts_seq):

                year = row[0]
                tif_district = row[1]
                return f'{year},{tif_district},{row[2] + 1}'

                break  
        else:

            maybe_contracts_index = 0
        
  



    maybe_contracts_seq2 = ['cash', "and","investments", "beginning", "of", "year"]
    maybe_contracts_index2 = 0
    
    
    for index, row in df.iterrows():
        word = row[12].lower()
        word = re.sub(r'[^\w\s]', '', word)  # removes non-alphanumeric characters
        page = row[2]

        if word == maybe_contracts_seq2[maybe_contracts_index2]:
            maybe_contracts_index2 += 1  

            if maybe_contracts_index2 == len(maybe_contracts_seq2):

                year = row[0]
                tif_district = row[1]
                return f'{year},{tif_district},{row[2] + 1}'

                break  
        else:

            maybe_contracts_index2 = 0
    
    return f'{y},{t},{-1}'

# %%
def parse_and_write_to_csv(folder_name, output_string):

    os.makedirs(folder_name, exist_ok=True)
    file_path = os.path.join(folder_name, "statements.csv")
    file_exists = os.path.isfile(file_path)
    
    with open(file_path, mode='a', newline='') as file: 
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(['Year', 'TIF', 'Page'])
        if output_string: 
            data = output_string.split(',')
            writer.writerow(data)

def process_all_csv_files(input_folder, output_folder):
    for filename in os.listdir(input_folder):
        if filename.endswith(".csv"):
            file_path = os.path.join(input_folder, filename)
            contract_status = find_sequence_with_pandas(file_path)
            parse_and_write_to_csv(output_folder, contract_status)
            print(f"Processed {filename}")

# %%
input_folder = "csv_files"
output_folder = "scraped"


process_all_csv_files(input_folder, output_folder)
# Out:
# Processed 1997_001.csv
# Processed 1997_002.csv
# Processed 1997_003.csv
# Processed 1997_004.csv
# Processed 1997_005.csv
# Processed 1997_006.csv
# Processed 1997_007.csv
# Processed 1997_008.csv
# Processed 1997_009.csv
# Processed 1997_010.csv
# Processed 1997_011.csv
# Processed 1997_012.csv
# Processed 1997_013.csv
# Processed 1997_014.csv
# Processed 1997_015.csv
# Processed 1997_017.csv
# Processed 1997_019.csv
# Processed 1997_020.csv
# Processed 1997_022.csv
# Processed 1997_023.csv
# Processed 1997_025.csv
# Processed 1997_026.csv
# Processed 1997_027.csv
# Processed 1997_028.csv
# Processed 1997_029.csv
# Processed 1997_030.csv
# Processed 1997_032.csv
# Processed 1997_035.csv
# Processed 1997_036.csv
# Processed 1997_037.csv
# Processed 1997_039.csv
# Processed 1997_040.csv
# Processed 1997_041.csv
# Processed 1997_042.csv
# Processed 1997_043.csv
# Processed 1997_044.csv
# Processed 1997_045.csv
# Processed 1997_046.csv
# Processed 1997_047.csv
# Processed 1998_001.csv
# Processed 1998_002.csv
# Processed 1998_003.csv
# Processed 1998_004.csv
# Processed 1998_005.csv
# Processed 1998_006.csv
# Processed 1998_007.csv
# Processed 1998_008.csv
# Processed 1998_009.csv
# Processed 1998_010.csv
# Processed 1998_011.csv
# Processed 1998_012.csv
# Processed 1998_013.csv
# Processed 1998_014.csv
# Processed 1998_015.csv
# Processed 1998_016.csv
# Processed 1998_019.csv
# Processed 1998_020.csv
# Processed 1998_022.csv
# Processed 1998_023.csv
# Processed 1998_024.csv
# Processed 1998_025.csv
# Processed 1998_026.csv
# Processed 1998_027.csv
# Processed 1998_028.csv
# Processed 1998_029.csv
# Processed 1998_031.csv
# Processed 1998_034.csv
# Processed 1998_035.csv
# Processed 1998_036.csv
# Processed 1998_037.csv
# Processed 1998_038.csv
# Processed 1998_039.csv
# Processed 1998_041.csv
# Processed 1998_042.csv
# Processed 1998_043.csv
# Processed 1998_044.csv
# Processed 1998_045.csv
# Processed 1998_046.csv
# Processed 1998_047.csv
# Processed 1998_050.csv
# Processed 1998_051.csv
# Processed 1998_053.csv
# Processed 1998_054.csv
# Processed 1998_055.csv
# Processed 1998_056.csv
# Processed 1998_057.csv
# Processed 1998_058.csv
# Processed 1998_059.csv
# Processed 1998_060.csv
# Processed 1998_061.csv
# Processed 1998_062.csv
# Processed 1998_064.csv
# Processed 1999_001.csv
# Processed 1999_002.csv
# Processed 1999_003.csv
# Processed 1999_004.csv
# Processed 1999_005.csv
# Processed 1999_006.csv
# Processed 1999_007.csv
# Processed 1999_009.csv
# Processed 1999_010.csv
# Processed 1999_011.csv
# Processed 1999_012.csv
# Processed 1999_013.csv
# Processed 1999_014.csv
# Processed 1999_015.csv
# Processed 1999_016.csv
# Processed 1999_017.csv
# Processed 1999_018.csv
# Processed 1999_019.csv
# Processed 1999_020.csv
# Processed 1999_021.csv
# Processed 1999_022.csv
# Processed 1999_024.csv
# Processed 1999_025.csv
# Processed 1999_026.csv
# Processed 1999_027.csv
# Processed 1999_028.csv
# Processed 1999_029.csv
# Processed 1999_030.csv
# Processed 1999_031.csv
# Processed 1999_032.csv
# Processed 1999_033.csv
# Processed 1999_034.csv
# Processed 1999_035.csv
# Processed 1999_036.csv
# Processed 1999_037.csv
# Processed 1999_038.csv
# Processed 1999_039.csv
# Processed 1999_040.csv
# Processed 1999_041.csv
# Processed 1999_042.csv
# Processed 1999_043.csv
# Processed 1999_044.csv
# Processed 1999_045.csv
# Processed 1999_046.csv
# Processed 1999_047.csv
# Processed 1999_048.csv
# Processed 1999_049.csv
# Processed 1999_050.csv
# Processed 1999_052.csv
# Processed 1999_053.csv
# Processed 1999_054.csv
# Processed 1999_055.csv
# Processed 1999_056.csv
# Processed 1999_057.csv
# Processed 1999_058.csv
# Processed 1999_059.csv
# Processed 1999_060.csv
# Processed 1999_061.csv
# Processed 1999_062.csv
# Processed 1999_063.csv
# Processed 1999_064.csv
# Processed 1999_065.csv
# Processed 1999_066.csv
# Processed 1999_067.csv
# Processed 1999_068.csv
# Processed 1999_069.csv
# Processed 1999_071.csv
# Processed 1999_073.csv
# Processed 1999_074.csv
# Processed 1999_075.csv
# Processed 1999_076.csv
# Processed 1999_077.csv
# Processed 1999_078.csv
# Processed 1999_079.csv
# Processed 1999_141.csv
# Processed 2000_001.csv
# Processed 2000_002.csv
# Processed 2000_003.csv
# Processed 2000_004.csv
# Processed 2000_005.csv
# Processed 2000_006.csv
# Processed 2000_007.csv
# Processed 2000_008.csv
# Processed 2000_009.csv
# Processed 2000_010.csv
# Processed 2000_011.csv
# Processed 2000_012.csv
# Processed 2000_013.csv
# Processed 2000_014.csv
# Processed 2000_015.csv
# Processed 2000_017.csv
# Processed 2000_018.csv
# Processed 2000_019.csv
# Processed 2000_020.csv
# Processed 2000_021.csv
# Processed 2000_022.csv
# Processed 2000_024.csv
# Processed 2000_025.csv
# Processed 2000_026.csv
# Processed 2000_027.csv
# Processed 2000_028.csv
# Processed 2000_029.csv
# Processed 2000_030.csv
# Processed 2000_031.csv
# Processed 2000_032.csv
# Processed 2000_033.csv
# Processed 2000_034.csv
# Processed 2000_035.csv
# Processed 2000_036.csv
# Processed 2000_037.csv
# Processed 2000_038.csv
# Processed 2000_039.csv
# Processed 2000_041.csv
# Processed 2000_042.csv
# Processed 2000_043.csv
# Processed 2000_045.csv
# Processed 2000_046.csv
# Processed 2000_047.csv
# Processed 2000_049.csv
# Processed 2000_050.csv
# Processed 2000_051.csv
# Processed 2000_052.csv
# Processed 2000_053.csv
# Processed 2000_054.csv
# Processed 2000_055.csv
# Processed 2000_056.csv
# Processed 2000_058.csv
# Processed 2000_059.csv
# Processed 2000_060.csv
# Processed 2000_061.csv
# Processed 2000_062.csv
# Processed 2000_063.csv
# Processed 2000_064.csv
# Processed 2000_065.csv
# Processed 2000_066.csv
# Processed 2000_067.csv
# Processed 2000_068.csv
# Processed 2000_069.csv
# Processed 2000_071.csv
# Processed 2000_073.csv
# Processed 2000_074.csv
# Processed 2000_075.csv
# Processed 2000_076.csv
# Processed 2000_077.csv
# Processed 2000_078.csv
# Processed 2000_079.csv
# Processed 2000_080.csv
# Processed 2000_081.csv
# Processed 2000_082.csv
# Processed 2000_083.csv
# Processed 2000_084.csv
# Processed 2000_085.csv
# Processed 2000_087.csv
# Processed 2000_089.csv
# Processed 2000_090.csv
# Processed 2000_091.csv
# Processed 2000_092.csv
# Processed 2000_093.csv
# Processed 2000_094.csv
# Processed 2000_096.csv
# Processed 2000_098.csv
# Processed 2000_099.csv
# Processed 2000_100.csv
# Processed 2000_101.csv
# Processed 2000_102.csv
# Processed 2000_103.csv
# Processed 2001_001.csv
# Processed 2001_002.csv
# Processed 2001_003.csv
# Processed 2001_004.csv
# Processed 2001_005.csv
# Processed 2001_006.csv
# Processed 2001_007.csv
# Processed 2001_008.csv
# Processed 2001_009.csv
# Processed 2001_010.csv
# Processed 2001_011.csv
# Processed 2001_012.csv
# Processed 2001_013.csv
# Processed 2001_014.csv
# Processed 2001_015.csv
# Processed 2001_017.csv
# Processed 2001_018.csv
# Processed 2001_019.csv
# Processed 2001_020.csv
# Processed 2001_021.csv
# Processed 2001_022.csv
# Processed 2001_023.csv
# Processed 2001_024.csv
# Processed 2001_025.csv
# Processed 2001_026.csv
# Processed 2001_027.csv
# Processed 2001_028.csv
# Processed 2001_029.csv
# Processed 2001_030.csv
# Processed 2001_031.csv
# Processed 2001_032.csv
# Processed 2001_033.csv
# Processed 2001_034.csv
# Processed 2001_035.csv
# Processed 2001_036.csv
# Processed 2001_037.csv
# Processed 2001_038.csv
# Processed 2001_039.csv
# Processed 2001_040.csv
# Processed 2001_041.csv
# Processed 2001_042.csv
# Processed 2001_043.csv
# Processed 2001_044.csv
# Processed 2001_045.csv
# Processed 2001_046.csv
# Processed 2001_047.csv
# Processed 2001_048.csv
# Processed 2001_049.csv
# Processed 2001_050.csv
# Processed 2001_051.csv
# Processed 2001_052.csv
# Processed 2001_053.csv
# Processed 2001_054.csv
# Processed 2001_055.csv
# Processed 2001_056.csv
# Processed 2001_057.csv
# Processed 2001_058.csv
# Processed 2001_059.csv
# Processed 2001_060.csv
# Processed 2001_061.csv
# Processed 2001_062.csv
# Processed 2001_063.csv
# Processed 2001_064.csv
# Processed 2001_065.csv
# Processed 2001_066.csv
# Processed 2001_067.csv
# Processed 2001_068.csv
# Processed 2001_069.csv
# Processed 2001_071.csv
# Processed 2001_073.csv
# Processed 2001_074.csv
# Processed 2001_075.csv
# Processed 2001_076.csv
# Processed 2001_077.csv
# Processed 2001_078.csv
# Processed 2001_079.csv
# Processed 2001_080.csv
# Processed 2001_081.csv
# Processed 2001_082.csv
# Processed 2001_083.csv
# Processed 2001_084.csv
# Processed 2001_085.csv
# Processed 2001_086.csv
# Processed 2001_087.csv
# Processed 2001_088.csv
# Processed 2001_089.csv
# Processed 2001_090.csv
# Processed 2001_091.csv
# Processed 2001_092.csv
# Processed 2001_093.csv
# Processed 2001_094.csv
# Processed 2001_095.csv
# Processed 2001_096.csv
# Processed 2001_098.csv
# Processed 2001_099.csv
# Processed 2001_100.csv
# Processed 2001_101.csv
# Processed 2001_102.csv
# Processed 2001_103.csv
# Processed 2001_104.csv
# Processed 2001_105.csv
# Processed 2001_106.csv
# Processed 2001_107.csv
# Processed 2001_108.csv
# Processed 2001_109.csv
# Processed 2001_110.csv
# Processed 2001_111.csv
# Processed 2001_112.csv
# Processed 2002_001.csv
# Processed 2002_002.csv
# Processed 2002_003.csv
# Processed 2002_004.csv
# Processed 2002_005.csv
# Processed 2002_006.csv
# Processed 2002_007.csv
# Processed 2002_008.csv
# Processed 2002_009.csv
# Processed 2002_010.csv
# Processed 2002_011.csv
# Processed 2002_012.csv
# Processed 2002_013.csv
# Processed 2002_014.csv
# Processed 2002_015.csv
# Processed 2002_017.csv
# Processed 2002_018.csv
# Processed 2002_019.csv
# Processed 2002_020.csv
# Processed 2002_021.csv
# Processed 2002_022.csv
# Processed 2002_023.csv
# Processed 2002_024.csv
# Processed 2002_025.csv
# Processed 2002_026.csv
# Processed 2002_027.csv
# Processed 2002_028.csv
# Processed 2002_029.csv
# Processed 2002_030.csv
# Processed 2002_031.csv
# Processed 2002_032.csv
# Processed 2002_033.csv
# Processed 2002_034.csv
# Processed 2002_035.csv
# Processed 2002_036.csv
# Processed 2002_037.csv
# Processed 2002_038.csv
# Processed 2002_039.csv
# Processed 2002_040.csv
# Processed 2002_041.csv
# Processed 2002_042.csv
# Processed 2002_043.csv
# Processed 2002_044.csv
# Processed 2002_045.csv
# Processed 2002_046.csv
# Processed 2002_047.csv
# Processed 2002_048.csv
# Processed 2002_049.csv
# Processed 2002_051.csv
# Processed 2002_052.csv
# Processed 2002_053.csv
# Processed 2002_054.csv
# Processed 2002_055.csv
# Processed 2002_056.csv
# Processed 2002_057.csv
# Processed 2002_058.csv
# Processed 2002_059.csv
# Processed 2002_060.csv
# Processed 2002_061.csv
# Processed 2002_062.csv
# Processed 2002_063.csv
# Processed 2002_064.csv
# Processed 2002_065.csv
# Processed 2002_067.csv
# Processed 2002_068.csv
# Processed 2002_069.csv
# Processed 2002_071.csv
# Processed 2002_073.csv
# Processed 2002_074.csv
# Processed 2002_075.csv
# Processed 2002_076.csv
# Processed 2002_077.csv
# Processed 2002_078.csv
# Processed 2002_079.csv
# Processed 2002_080.csv
# Processed 2002_081.csv
# Processed 2002_082.csv
# Processed 2002_083.csv
# Processed 2002_084.csv
# Processed 2002_085.csv
# Processed 2002_086.csv
# Processed 2002_087.csv
# Processed 2002_088.csv
# Processed 2002_089.csv
# Processed 2002_090.csv
# Processed 2002_091.csv
# Processed 2002_092.csv
# Processed 2002_093.csv
# Processed 2002_094.csv
# Processed 2002_095.csv
# Processed 2002_096.csv
# Processed 2002_097.csv
# Processed 2002_098.csv
# Processed 2002_099.csv
# Processed 2002_100.csv
# Processed 2002_101.csv
# Processed 2002_102.csv
# Processed 2002_103.csv
# Processed 2002_104.csv
# Processed 2002_105.csv
# Processed 2002_106.csv
# Processed 2002_107.csv
# Processed 2002_108.csv
# Processed 2002_109.csv
# Processed 2002_110.csv
# Processed 2002_111.csv
# Processed 2002_112.csv
# Processed 2002_113.csv
# Processed 2002_114.csv
# Processed 2002_115.csv
# Processed 2002_116.csv
# Processed 2002_117.csv
# Processed 2002_118.csv
# Processed 2002_119.csv
# Processed 2002_121.csv
# Processed 2002_122.csv
# Processed 2002_124.csv
# Processed 2002_125.csv
# Processed 2002_126.csv
# Processed 2002_127.csv
# Processed 2002_128.csv
# Processed 2003_001.csv
# Processed 2003_002.csv
# Processed 2003_003.csv
# Processed 2003_004.csv
# Processed 2003_005.csv
# Processed 2003_006.csv
# Processed 2003_007.csv
# Processed 2003_008.csv
# Processed 2003_009.csv
# Processed 2003_010.csv
# Processed 2003_011.csv
# Processed 2003_012.csv
# Processed 2003_013.csv
# Processed 2003_014.csv
# Processed 2003_015.csv
# Processed 2003_017.csv
# Processed 2003_018.csv
# Processed 2003_019.csv
# Processed 2003_020.csv
# Processed 2003_021.csv
# Processed 2003_022.csv
# Processed 2003_023.csv
# Processed 2003_024.csv
# Processed 2003_025.csv
# Processed 2003_026.csv
# Processed 2003_027.csv
# Processed 2003_028.csv
# Processed 2003_029.csv
# Processed 2003_030.csv
# Processed 2003_031.csv
# Processed 2003_032.csv
# Processed 2003_033.csv
# Processed 2003_034.csv
# Processed 2003_035.csv
# Processed 2003_036.csv
# Processed 2003_037.csv
# Processed 2003_038.csv
# Processed 2003_039.csv
# Processed 2003_040.csv
# Processed 2003_041.csv
# Processed 2003_042.csv
# Processed 2003_043.csv
# Processed 2003_044.csv
# Processed 2003_045.csv
# Processed 2003_046.csv
# Processed 2003_047.csv
# Processed 2003_048.csv
# Processed 2003_049.csv
# Processed 2003_050.csv
# Processed 2003_051.csv
# Processed 2003_052.csv
# Processed 2003_053.csv
# Processed 2003_054.csv
# Processed 2003_055.csv
# Processed 2003_056.csv
# Processed 2003_057.csv
# Processed 2003_058.csv
# Processed 2003_059.csv
# Processed 2003_060.csv
# Processed 2003_061.csv
# Processed 2003_062.csv
# Processed 2003_063.csv
# Processed 2003_064.csv
# Processed 2003_065.csv
# Processed 2003_067.csv
# Processed 2003_068.csv
# Processed 2003_069.csv
# Processed 2003_071.csv
# Processed 2003_073.csv
# Processed 2003_074.csv
# Processed 2003_075.csv
# Processed 2003_076.csv
# Processed 2003_077.csv
# Processed 2003_078.csv
# Processed 2003_079.csv
# Processed 2003_080.csv
# Processed 2003_081.csv
# Processed 2003_082.csv
# Processed 2003_083.csv
# Processed 2003_084.csv
# Processed 2003_085.csv
# Processed 2003_086.csv
# Processed 2003_087.csv
# Processed 2003_088.csv
# Processed 2003_089.csv
# Processed 2003_090.csv
# Processed 2003_091.csv
# Processed 2003_092.csv
# Processed 2003_093.csv
# Processed 2003_094.csv
# Processed 2003_095.csv
# Processed 2003_096.csv
# Processed 2003_097.csv
# Processed 2003_098.csv
# Processed 2003_099.csv
# Processed 2003_100.csv
# Processed 2003_101.csv
# Processed 2003_102.csv
# Processed 2003_103.csv
# Processed 2003_104.csv
# Processed 2003_105.csv
# Processed 2003_106.csv
# Processed 2003_107.csv
# Processed 2003_108.csv
# Processed 2003_109.csv
# Processed 2003_110.csv
# Processed 2003_111.csv
# Processed 2003_112.csv
# Processed 2003_113.csv
# Processed 2003_114.csv
# Processed 2003_115.csv
# Processed 2003_116.csv
# Processed 2003_117.csv
# Processed 2003_118.csv
# Processed 2003_119.csv
# Processed 2003_121.csv
# Processed 2003_122.csv
# Processed 2003_124.csv
# Processed 2003_125.csv
# Processed 2003_126.csv
# Processed 2003_127.csv
# Processed 2003_128.csv
# Processed 2004_001.csv
# Processed 2004_002.csv
# Processed 2004_003.csv
# Processed 2004_004.csv
# Processed 2004_005.csv
# Processed 2004_006.csv
# Processed 2004_007.csv
# Processed 2004_008.csv
# Processed 2004_009.csv
# Processed 2004_010.csv
# Processed 2004_011.csv
# Processed 2004_012.csv
# Processed 2004_013.csv
# Processed 2004_014.csv
# Processed 2004_015.csv
# Processed 2004_016.csv
# Processed 2004_017.csv
# Processed 2004_018.csv
# Processed 2004_019.csv
# Processed 2004_020.csv
# Processed 2004_021.csv
# Processed 2004_023.csv
# Processed 2004_024.csv
# Processed 2004_025.csv
# Processed 2004_026.csv
# Processed 2004_027.csv
# Processed 2004_028.csv
# Processed 2004_029.csv
# Processed 2004_030.csv
# Processed 2004_031.csv
# Processed 2004_032.csv
# Processed 2004_033.csv
# Processed 2004_034.csv
# Processed 2004_035.csv
# Processed 2004_036.csv
# Processed 2004_037.csv
# Processed 2004_038.csv
# Processed 2004_039.csv
# Processed 2004_040.csv
# Processed 2004_041.csv
# Processed 2004_042.csv
# Processed 2004_043.csv
# Processed 2004_044.csv
# Processed 2004_045.csv
# Processed 2004_046.csv
# Processed 2004_047.csv
# Processed 2004_048.csv
# Processed 2004_049.csv
# Processed 2004_050.csv
# Processed 2004_051.csv
# Processed 2004_052.csv
# Processed 2004_053.csv
# Processed 2004_054.csv
# Processed 2004_055.csv
# Processed 2004_056.csv
# Processed 2004_057.csv
# Processed 2004_058.csv
# Processed 2004_059.csv
# Processed 2004_060.csv
# Processed 2004_061.csv
# Processed 2004_062.csv
# Processed 2004_063.csv
# Processed 2004_064.csv
# Processed 2004_065.csv
# Processed 2004_066.csv
# Processed 2004_067.csv
# Processed 2004_068.csv
# Processed 2004_069.csv
# Processed 2004_070.csv
# Processed 2004_071.csv
# Processed 2004_072.csv
# Processed 2004_073.csv
# Processed 2004_074.csv
# Processed 2004_075.csv
# Processed 2004_076.csv
# Processed 2004_077.csv
# Processed 2004_078.csv
# Processed 2004_079.csv
# Processed 2004_080.csv
# Processed 2004_081.csv
# Processed 2004_082.csv
# Processed 2004_083.csv
# Processed 2004_084.csv
# Processed 2004_085.csv
# Processed 2004_086.csv
# Processed 2004_087.csv
# Processed 2004_088.csv
# Processed 2004_089.csv
# Processed 2004_090.csv
# Processed 2004_091.csv
# Processed 2004_092.csv
# Processed 2004_093.csv
# Processed 2004_094.csv
# Processed 2004_095.csv
# Processed 2004_096.csv
# Processed 2004_097.csv
# Processed 2004_098.csv
# Processed 2004_099.csv
# Processed 2004_100.csv
# Processed 2004_101.csv
# Processed 2004_102.csv
# Processed 2004_103.csv
# Processed 2004_104.csv
# Processed 2004_105.csv
# Processed 2004_106.csv
# Processed 2004_107.csv
# Processed 2004_108.csv
# Processed 2004_109.csv
# Processed 2004_110.csv
# Processed 2004_111.csv
# Processed 2004_112.csv
# Processed 2004_113.csv
# Processed 2004_114.csv
# Processed 2004_115.csv
# Processed 2004_116.csv
# Processed 2004_117.csv
# Processed 2004_118.csv
# Processed 2004_119.csv
# Processed 2004_120.csv
# Processed 2004_121.csv
# Processed 2004_122.csv
# Processed 2004_123.csv
# Processed 2004_124.csv
# Processed 2004_125.csv
# Processed 2004_126.csv
# Processed 2004_127.csv
# Processed 2004_128.csv
# Processed 2004_129.csv
# Processed 2004_130.csv
# Processed 2004_131.csv
# Processed 2004_132.csv
# Processed 2004_133.csv
# Processed 2004_134.csv
# Processed 2004_135.csv
# Processed 2004_136.csv
# Processed 2004_137.csv
# Processed 2004_138.csv
# Processed 2005_001.csv
# Processed 2005_002.csv
# Processed 2005_003.csv
# Processed 2005_004.csv
# Processed 2005_005.csv
# Processed 2005_006.csv
# Processed 2005_007.csv
# Processed 2005_008.csv
# Processed 2005_009.csv
# Processed 2005_010.csv
# Processed 2005_011.csv
# Processed 2005_012.csv
# Processed 2005_013.csv
# Processed 2005_014.csv
# Processed 2005_015.csv
# Processed 2005_016.csv
# Processed 2005_017.csv
# Processed 2005_018.csv
# Processed 2005_019.csv
# Processed 2005_020.csv
# Processed 2005_021.csv
# Processed 2005_023.csv
# Processed 2005_024.csv
# Processed 2005_025.csv
# Processed 2005_026.csv
# Processed 2005_027.csv
# Processed 2005_028.csv
# Processed 2005_029.csv
# Processed 2005_030.csv
# Processed 2005_031.csv
# Processed 2005_032.csv
# Processed 2005_033.csv
# Processed 2005_034.csv
# Processed 2005_035.csv
# Processed 2005_036.csv
# Processed 2005_037.csv
# Processed 2005_038.csv
# Processed 2005_039.csv
# Processed 2005_040.csv
# Processed 2005_041.csv
# Processed 2005_042.csv
# Processed 2005_043.csv
# Processed 2005_044.csv
# Processed 2005_045.csv
# Processed 2005_046.csv
# Processed 2005_047.csv
# Processed 2005_048.csv
# Processed 2005_049.csv
# Processed 2005_050.csv
# Processed 2005_051.csv
# Processed 2005_052.csv
# Processed 2005_053.csv
# Processed 2005_054.csv
# Processed 2005_055.csv
# Processed 2005_056.csv
# Processed 2005_057.csv
# Processed 2005_058.csv
# Processed 2005_059.csv
# Processed 2005_060.csv
# Processed 2005_061.csv
# Processed 2005_062.csv
# Processed 2005_063.csv
# Processed 2005_064.csv
# Processed 2005_065.csv
# Processed 2005_066.csv
# Processed 2005_067.csv
# Processed 2005_068.csv
# Processed 2005_069.csv
# Processed 2005_070.csv
# Processed 2005_071.csv
# Processed 2005_072.csv
# Processed 2005_073.csv
# Processed 2005_074.csv
# Processed 2005_076.csv
# Processed 2005_077.csv
# Processed 2005_078.csv
# Processed 2005_079.csv
# Processed 2005_080.csv
# Processed 2005_081.csv
# Processed 2005_082.csv
# Processed 2005_083.csv
# Processed 2005_084.csv
# Processed 2005_085.csv
# Processed 2005_086.csv
# Processed 2005_087.csv
# Processed 2005_088.csv
# Processed 2005_089.csv
# Processed 2005_090.csv
# Processed 2005_091.csv
# Processed 2005_092.csv
# Processed 2005_093.csv
# Processed 2005_094.csv
# Processed 2005_095.csv
# Processed 2005_096.csv
# Processed 2005_097.csv
# Processed 2005_098.csv
# Processed 2005_099.csv
# Processed 2005_100.csv
# Processed 2005_101.csv
# Processed 2005_102.csv
# Processed 2005_103.csv
# Processed 2005_104.csv
# Processed 2005_105.csv
# Processed 2005_106.csv
# Processed 2005_107.csv
# Processed 2005_108.csv
# Processed 2005_109.csv
# Processed 2005_110.csv
# Processed 2005_111.csv
# Processed 2005_113.csv
# Processed 2005_114.csv
# Processed 2005_115.csv
# Processed 2005_116.csv
# Processed 2005_117.csv
# Processed 2005_118.csv
# Processed 2005_119.csv
# Processed 2005_120.csv
# Processed 2005_121.csv
# Processed 2005_122.csv
# Processed 2005_123.csv
# Processed 2005_124.csv
# Processed 2005_125.csv
# Processed 2005_126.csv
# Processed 2005_127.csv
# Processed 2005_128.csv
# Processed 2005_129.csv
# Processed 2005_130.csv
# Processed 2005_131.csv
# Processed 2005_132.csv
# Processed 2005_133.csv
# Processed 2005_134.csv
# Processed 2005_135.csv
# Processed 2005_136.csv
# Processed 2005_137.csv
# Processed 2005_138.csv
# Processed 2005_139.csv
# Processed 2005_140.csv
# Processed 2006_001.csv
# Processed 2006_002.csv
# Processed 2006_003.csv
# Processed 2006_004.csv
# Processed 2006_005.csv
# Processed 2006_006.csv
# Processed 2006_007.csv
# Processed 2006_008.csv
# Processed 2006_009.csv
# Processed 2006_010.csv
# Processed 2006_011.csv
# Processed 2006_012.csv
# Processed 2006_013.csv
# Processed 2006_014.csv
# Processed 2006_015.csv
# Processed 2006_016.csv
# Processed 2006_017.csv
# Processed 2006_018.csv
# Processed 2006_019.csv
# Processed 2006_020.csv
# Processed 2006_021.csv
# Processed 2006_023.csv
# Processed 2006_024.csv
# Processed 2006_025.csv
# Processed 2006_026.csv
# Processed 2006_027.csv
# Processed 2006_028.csv
# Processed 2006_029.csv
# Processed 2006_030.csv
# Processed 2006_031.csv
# Processed 2006_032.csv
# Processed 2006_033.csv
# Processed 2006_034.csv
# Processed 2006_035.csv
# Processed 2006_036.csv
# Processed 2006_037.csv
# Processed 2006_038.csv
# Processed 2006_039.csv
# Processed 2006_040.csv
# Processed 2006_041.csv
# Processed 2006_042.csv
# Processed 2006_043.csv
# Processed 2006_044.csv
# Processed 2006_045.csv
# Processed 2006_046.csv
# Processed 2006_047.csv
# Processed 2006_048.csv
# Processed 2006_049.csv
# Processed 2006_050.csv
# Processed 2006_051.csv
# Processed 2006_052.csv
# Processed 2006_053.csv
# Processed 2006_054.csv
# Processed 2006_055.csv
# Processed 2006_056.csv
# Processed 2006_057.csv
# Processed 2006_058.csv
# Processed 2006_059.csv
# Processed 2006_060.csv
# Processed 2006_061.csv
# Processed 2006_062.csv
# Processed 2006_063.csv
# Processed 2006_064.csv
# Processed 2006_065.csv
# Processed 2006_066.csv
# Processed 2006_067.csv
# Processed 2006_068.csv
# Processed 2006_069.csv
# Processed 2006_070.csv
# Processed 2006_071.csv
# Processed 2006_072.csv
# Processed 2006_073.csv
# Processed 2006_074.csv
# Processed 2006_075.csv
# Processed 2006_076.csv
# Processed 2006_077.csv
# Processed 2006_078.csv
# Processed 2006_079.csv
# Processed 2006_080.csv
# Processed 2006_081.csv
# Processed 2006_082.csv
# Processed 2006_083.csv
# Processed 2006_084.csv
# Processed 2006_085.csv
# Processed 2006_086.csv
# Processed 2006_087.csv
# Processed 2006_088.csv
# Processed 2006_089.csv
# Processed 2006_090.csv
# Processed 2006_091.csv
# Processed 2006_092.csv
# Processed 2006_093.csv
# Processed 2006_094.csv
# Processed 2006_095.csv
# Processed 2006_096.csv
# Processed 2006_097.csv
# Processed 2006_098.csv
# Processed 2006_099.csv
# Processed 2006_100.csv
# Processed 2006_101.csv
# Processed 2006_102.csv
# Processed 2006_103.csv
# Processed 2006_104.csv
# Processed 2006_105.csv
# Processed 2006_106.csv
# Processed 2006_107.csv
# Processed 2006_108.csv
# Processed 2006_109.csv
# Processed 2006_110.csv
# Processed 2006_111.csv
# Processed 2006_112.csv
# Processed 2006_113.csv
# Processed 2006_114.csv
# Processed 2006_115.csv
# Processed 2006_116.csv
# Processed 2006_117.csv
# Processed 2006_118.csv
# Processed 2006_119.csv
# Processed 2006_120.csv
# Processed 2006_121.csv
# Processed 2006_122.csv
# Processed 2006_123.csv
# Processed 2006_124.csv
# Processed 2006_125.csv
# Processed 2006_126.csv
# Processed 2006_127.csv
# Processed 2006_128.csv
# Processed 2006_129.csv
# Processed 2006_130.csv
# Processed 2006_131.csv
# Processed 2006_132.csv
# Processed 2006_133.csv
# Processed 2006_134.csv
# Processed 2006_135.csv
# Processed 2006_136.csv
# Processed 2006_137.csv
# Processed 2006_138.csv
# Processed 2006_139.csv
# Processed 2006_140.csv
# Processed 2006_141.csv
# Processed 2006_142.csv
# Processed 2006_143.csv
# Processed 2006_144.csv
# Processed 2006_145.csv
# Processed 2006_146.csv
# Processed 2006_147.csv
# Processed 2007_001.csv
# Processed 2007_002.csv
# Processed 2007_003.csv
# Processed 2007_004.csv
# Processed 2007_005.csv
# Processed 2007_006.csv
# Processed 2007_007.csv
# Processed 2007_008.csv
# Processed 2007_009.csv
# Processed 2007_010.csv
# Processed 2007_011.csv
# Processed 2007_012.csv
# Processed 2007_013.csv
# Processed 2007_014.csv
# Processed 2007_015.csv
# Processed 2007_016.csv
# Processed 2007_017.csv
# Processed 2007_018.csv
# Processed 2007_019.csv
# Processed 2007_020.csv
# Processed 2007_021.csv
# Processed 2007_023.csv
# Processed 2007_024.csv
# Processed 2007_025.csv
# Processed 2007_026.csv
# Processed 2007_027.csv
# Processed 2007_028.csv
# Processed 2007_029.csv
# Processed 2007_030.csv
# Processed 2007_031.csv
# Processed 2007_032.csv
# Processed 2007_033.csv
# Processed 2007_034.csv
# Processed 2007_035.csv
# Processed 2007_036.csv
# Processed 2007_037.csv
# Processed 2007_038.csv
# Processed 2007_039.csv
# Processed 2007_040.csv
# Processed 2007_041.csv
# Processed 2007_042.csv
# Processed 2007_043.csv
# Processed 2007_044.csv
# Processed 2007_045.csv
# Processed 2007_046.csv
# Processed 2007_047.csv
# Processed 2007_048.csv
# Processed 2007_049.csv
# Processed 2007_050.csv
# Processed 2007_051.csv
# Processed 2007_052.csv
# Processed 2007_053.csv
# Processed 2007_054.csv
# Processed 2007_055.csv
# Processed 2007_056.csv
# Processed 2007_057.csv
# Processed 2007_058.csv
# Processed 2007_059.csv
# Processed 2007_060.csv
# Processed 2007_061.csv
# Processed 2007_062.csv
# Processed 2007_063.csv
# Processed 2007_064.csv
# Processed 2007_065.csv
# Processed 2007_066.csv
# Processed 2007_067.csv
# Processed 2007_068.csv
# Processed 2007_069.csv
# Processed 2007_070.csv
# Processed 2007_071.csv
# Processed 2007_072.csv
# Processed 2007_073.csv
# Processed 2007_074.csv
# Processed 2007_075.csv
# Processed 2007_076.csv
# Processed 2007_077.csv
# Processed 2007_078.csv
# Processed 2007_079.csv
# Processed 2007_080.csv
# Processed 2007_081.csv
# Processed 2007_082.csv
# Processed 2007_083.csv
# Processed 2007_084.csv
# Processed 2007_085.csv
# Processed 2007_086.csv
# Processed 2007_087.csv
# Processed 2007_088.csv
# Processed 2007_089.csv
# Processed 2007_090.csv
# Processed 2007_091.csv
# Processed 2007_092.csv
# Processed 2007_093.csv
# Processed 2007_094.csv
# Processed 2007_095.csv
# Processed 2007_096.csv
# Processed 2007_097.csv
# Processed 2007_098.csv
# Processed 2007_099.csv
# Processed 2007_100.csv
# Processed 2007_101.csv
# Processed 2007_102.csv
# Processed 2007_103.csv
# Processed 2007_104.csv
# Processed 2007_105.csv
# Processed 2007_106.csv
# Processed 2007_107.csv
# Processed 2007_108.csv
# Processed 2007_109.csv
# Processed 2007_110.csv
# Processed 2007_111.csv
# Processed 2007_112.csv
# Processed 2007_113.csv
# Processed 2007_114.csv
# Processed 2007_115.csv
# Processed 2007_116.csv
# Processed 2007_117.csv
# Processed 2007_118.csv
# Processed 2007_119.csv
# Processed 2007_120.csv
# Processed 2007_121.csv
# Processed 2007_122.csv
# Processed 2007_123.csv
# Processed 2007_124.csv
# Processed 2007_125.csv
# Processed 2007_126.csv
# Processed 2007_127.csv
# Processed 2007_128.csv
# Processed 2007_129.csv
# Processed 2007_130.csv
# Processed 2007_131.csv
# Processed 2007_132.csv
# Processed 2007_133.csv
# Processed 2007_134.csv
# Processed 2007_135.csv
# Processed 2007_136.csv
# Processed 2007_137.csv
# Processed 2007_138.csv
# Processed 2007_139.csv
# Processed 2007_140.csv
# Processed 2007_141.csv
# Processed 2007_142.csv
# Processed 2007_143.csv
# Processed 2007_144.csv
# Processed 2007_145.csv
# Processed 2007_146.csv
# Processed 2007_147.csv
# Processed 2007_148.csv
# Processed 2007_149.csv
# Processed 2007_150.csv
# Processed 2007_151.csv
# Processed 2007_152.csv
# Processed 2007_153.csv
# Processed 2007_154.csv
# Processed 2007_155.csv
# Processed 2007_156.csv
# Processed 2007_157.csv
# Processed 2008_001.csv
# Processed 2008_002.csv
# Processed 2008_003.csv
# Processed 2008_004.csv
# Processed 2008_005.csv
# Processed 2008_006.csv
# Processed 2008_007.csv
# Processed 2008_008.csv
# Processed 2008_009.csv
# Processed 2008_010.csv
# Processed 2008_011.csv
# Processed 2008_012.csv
# Processed 2008_013.csv
# Processed 2008_014.csv
# Processed 2008_015.csv
# Processed 2008_016.csv
# Processed 2008_017.csv
# Processed 2008_018.csv
# Processed 2008_019.csv
# Processed 2008_020.csv
# Processed 2008_021.csv
# Processed 2008_023.csv
# Processed 2008_024.csv
# Processed 2008_025.csv
# Processed 2008_026.csv
# Processed 2008_027.csv
# Processed 2008_028.csv
# Processed 2008_029.csv
# Processed 2008_030.csv
# Processed 2008_031.csv
# Processed 2008_032.csv
# Processed 2008_033.csv
# Processed 2008_034.csv
# Processed 2008_035.csv
# Processed 2008_036.csv
# Processed 2008_037.csv
# Processed 2008_038.csv
# Processed 2008_039.csv
# Processed 2008_040.csv
# Processed 2008_041.csv
# Processed 2008_042.csv
# Processed 2008_043.csv
# Processed 2008_044.csv
# Processed 2008_045.csv
# Processed 2008_046.csv
# Processed 2008_047.csv
# Processed 2008_048.csv
# Processed 2008_049.csv
# Processed 2008_050.csv
# Processed 2008_051.csv
# Processed 2008_052.csv
# Processed 2008_053.csv
# Processed 2008_054.csv
# Processed 2008_055.csv
# Processed 2008_056.csv
# Processed 2008_057.csv
# Processed 2008_058.csv
# Processed 2008_059.csv
# Processed 2008_060.csv
# Processed 2008_061.csv
# Processed 2008_062.csv
# Processed 2008_063.csv
# Processed 2008_064.csv
# Processed 2008_065.csv
# Processed 2008_066.csv
# Processed 2008_067.csv
# Processed 2008_068.csv
# Processed 2008_069.csv
# Processed 2008_070.csv
# Processed 2008_071.csv
# Processed 2008_072.csv
# Processed 2008_073.csv
# Processed 2008_074.csv
# Processed 2008_075.csv
# Processed 2008_076.csv
# Processed 2008_077.csv
# Processed 2008_078.csv
# Processed 2008_079.csv
# Processed 2008_080.csv
# Processed 2008_081.csv
# Processed 2008_082.csv
# Processed 2008_083.csv
# Processed 2008_084.csv
# Processed 2008_085.csv
# Processed 2008_086.csv
# Processed 2008_087.csv
# Processed 2008_088.csv
# Processed 2008_089.csv
# Processed 2008_090.csv
# Processed 2008_091.csv
# Processed 2008_092.csv
# Processed 2008_093.csv
# Processed 2008_094.csv
# Processed 2008_095.csv
# Processed 2008_096.csv
# Processed 2008_097.csv
# Processed 2008_098.csv
# Processed 2008_099.csv
# Processed 2008_100.csv
# Processed 2008_101.csv
# Processed 2008_102.csv
# Processed 2008_103.csv
# Processed 2008_104.csv
# Processed 2008_105.csv
# Processed 2008_106.csv
# Processed 2008_107.csv
# Processed 2008_108.csv
# Processed 2008_109.csv
# Processed 2008_110.csv
# Processed 2008_111.csv
# Processed 2008_112.csv
# Processed 2008_113.csv
# Processed 2008_114.csv
# Processed 2008_115.csv
# Processed 2008_116.csv
# Processed 2008_117.csv
# Processed 2008_118.csv
# Processed 2008_119.csv
# Processed 2008_120.csv
# Processed 2008_121.csv
# Processed 2008_122.csv
# Processed 2008_123.csv
# Processed 2008_124.csv
# Processed 2008_125.csv
# Processed 2008_126.csv
# Processed 2008_127.csv
# Processed 2008_128.csv
# Processed 2008_129.csv
# Processed 2008_130.csv
# Processed 2008_131.csv
# Processed 2008_132.csv
# Processed 2008_133.csv
# Processed 2008_134.csv
# Processed 2008_135.csv
# Processed 2008_136.csv
# Processed 2008_137.csv
# Processed 2008_138.csv
# Processed 2008_139.csv
# Processed 2008_140.csv
# Processed 2008_141.csv
# Processed 2008_142.csv
# Processed 2008_143.csv
# Processed 2008_144.csv
# Processed 2008_145.csv
# Processed 2008_146.csv
# Processed 2008_147.csv
# Processed 2008_148.csv
# Processed 2008_149.csv
# Processed 2008_150.csv
# Processed 2008_151.csv
# Processed 2008_152.csv
# Processed 2008_153.csv
# Processed 2008_154.csv
# Processed 2008_155.csv
# Processed 2008_156.csv
# Processed 2008_157.csv
# Processed 2008_158.csv
# Processed 2008_159.csv
# Processed 2008_160.csv
# Processed 2008_161.csv
# Processed 2008_162.csv
# Processed 2009_001.csv
# Processed 2009_002.csv
# Processed 2009_004.csv
# Processed 2009_005.csv
# Processed 2009_006.csv
# Processed 2009_007.csv
# Processed 2009_008.csv
# Processed 2009_009.csv
# Processed 2009_010.csv
# Processed 2009_011.csv
# Processed 2009_013.csv
# Processed 2009_015.csv
# Processed 2009_016.csv
# Processed 2009_017.csv
# Processed 2009_018.csv
# Processed 2009_019.csv
# Processed 2009_020.csv
# Processed 2009_021.csv
# Processed 2009_023.csv
# Processed 2009_024.csv
# Processed 2009_025.csv
# Processed 2009_026.csv
# Processed 2009_027.csv
# Processed 2009_028.csv
# Processed 2009_029.csv
# Processed 2009_030.csv
# Processed 2009_031.csv
# Processed 2009_032.csv
# Processed 2009_033.csv
# Processed 2009_034.csv
# Processed 2009_035.csv
# Processed 2009_036.csv
# Processed 2009_037.csv
# Processed 2009_038.csv
# Processed 2009_039.csv
# Processed 2009_040.csv
# Processed 2009_042.csv
# Processed 2009_043.csv
# Processed 2009_044.csv
# Processed 2009_045.csv
# Processed 2009_046.csv
# Processed 2009_047.csv
# Processed 2009_048.csv
# Processed 2009_049.csv
# Processed 2009_050.csv
# Processed 2009_052.csv
# Processed 2009_053.csv
# Processed 2009_054.csv
# Processed 2009_055.csv
# Processed 2009_056.csv
# Processed 2009_057.csv
# Processed 2009_058.csv
# Processed 2009_059.csv
# Processed 2009_060.csv
# Processed 2009_061.csv
# Processed 2009_062.csv
# Processed 2009_063.csv
# Processed 2009_064.csv
# Processed 2009_065.csv
# Processed 2009_066.csv
# Processed 2009_067.csv
# Processed 2009_068.csv
# Processed 2009_069.csv
# Processed 2009_070.csv
# Processed 2009_071.csv
# Processed 2009_072.csv
# Processed 2009_073.csv
# Processed 2009_074.csv
# Processed 2009_075.csv
# Processed 2009_076.csv
# Processed 2009_077.csv
# Processed 2009_078.csv
# Processed 2009_079.csv
# Processed 2009_081.csv
# Processed 2009_082.csv
# Processed 2009_083.csv
# Processed 2009_084.csv
# Processed 2009_085.csv
# Processed 2009_086.csv
# Processed 2009_087.csv
# Processed 2009_088.csv
# Processed 2009_089.csv
# Processed 2009_090.csv
# Processed 2009_091.csv
# Processed 2009_092.csv
# Processed 2009_093.csv
# Processed 2009_094.csv
# Processed 2009_095.csv
# Processed 2009_096.csv
# Processed 2009_097.csv
# Processed 2009_098.csv
# Processed 2009_099.csv
# Processed 2009_100.csv
# Processed 2009_101.csv
# Processed 2009_102.csv
# Processed 2009_103.csv
# Processed 2009_104.csv
# Processed 2009_105.csv
# Processed 2009_106.csv
# Processed 2009_107.csv
# Processed 2009_108.csv
# Processed 2009_109.csv
# Processed 2009_110.csv
# Processed 2009_111.csv
# Processed 2009_112.csv
# Processed 2009_113.csv
# Processed 2009_114.csv
# Processed 2009_115.csv
# Processed 2009_116.csv
# Processed 2009_117.csv
# Processed 2009_118.csv
# Processed 2009_119.csv
# Processed 2009_120.csv
# Processed 2009_121.csv
# Processed 2009_122.csv
# Processed 2009_123.csv
# Processed 2009_124.csv
# Processed 2009_125.csv
# Processed 2009_126.csv
# Processed 2009_127.csv
# Processed 2009_128.csv
# Processed 2009_129.csv
# Processed 2009_130.csv
# Processed 2009_131.csv
# Processed 2009_132.csv
# Processed 2009_133.csv
# Processed 2009_134.csv
# Processed 2009_135.csv
# Processed 2009_136.csv
# Processed 2009_137.csv
# Processed 2009_138.csv
# Processed 2009_139.csv
# Processed 2009_140.csv
# Processed 2009_141.csv
# Processed 2009_142.csv
# Processed 2009_143.csv
# Processed 2009_144.csv
# Processed 2009_145.csv
# Processed 2009_146.csv
# Processed 2009_147.csv
# Processed 2009_148.csv
# Processed 2009_149.csv
# Processed 2009_150.csv
# Processed 2009_151.csv
# Processed 2009_152.csv
# Processed 2009_153.csv
# Processed 2009_154.csv
# Processed 2009_155.csv
# Processed 2009_156.csv
# Processed 2009_157.csv
# Processed 2009_158.csv
# Processed 2009_159.csv
# Processed 2009_160.csv
# Processed 2009_161.csv
# Processed 2009_162.csv
# Processed 2009_163.csv
# Processed 2009_164.csv
# Processed 2009_165.csv
# Processed 2009_166.csv
# Processed 2009_167.csv

# %%
import os
import glob
import pandas as pd
from PyPDF2 import PdfReader
from pdf2image import convert_from_path
from PIL import Image

def findBottom(year,tif,page_number):
    tif = f"{int(tif):03d}"
    filename = f"csv_files/{year}_{tif}.csv"
    
    df_bot = pd.read_csv(filename)
    filtered_df = df_bot[df_bot.iloc[:, 2] == page_number]
    
    filtered_values = filtered_df[filtered_df.iloc[:, 8] < 2600].iloc[:, 8]

    # Find the maximum value in the filtered DataFrame
    max_value = filtered_values.max()
    
    return max_value


def open_pdf_and_convert_to_image(df, base_directory):
    for index, row in df.iterrows():
        year = row['Year']
        tif = f"{row['TIF']:03}"  # Ensure TIF number is zero-padded to three digits
        page_number = row['Page'] - 1  # Adjust for zero-indexed page numbers
        
        if index == 0:
             current_year = year
                
        
        
        # Construct the directory path for the given year
        year_directory = os.path.join(base_directory, str(year))
        
        if not os.path.exists(year_directory):
            print(f"Directory for year {year} does not exist.")
            continue

        # Find the PDF file starting with 'T_TIFnumber'
        pattern = os.path.join(year_directory, f"T_{tif}_*.pdf")
        files = glob.glob(pattern)

        if not files:
            print(f"No PDF file found for TIF {tif} in year {year}.")
            continue

        # Open and convert the specified page of the first matching PDF file
        pdf_file_path = files[0]
        try:
            # Using pdf2image to convert the page to an image with specified DPI for higher resolution
            images = convert_from_path(pdf_file_path, first_page=page_number+1, last_page=page_number+1, dpi=300, poppler_path="C:/Users/wesam/OneDrive/Documents/poppler-24.02.0/Library/bin")
            if images:
                # Display the image of the specified page
                image = images[0]

                # Define the bounding box to crop the image (left, upper, right, lower)
                # Example: Crop the center of the image
                width, height = image.size
                left = 100
                top = 600
                right = width - 100
                bottom = findBottom(year,tif,page_number) + 200
 
                cropped_image = image.crop((left, top, right, bottom))

                cropped_image.show()
                print(f"Displayed {year}_{tif}")
            else:
                print(f"No content on page {page_number+1} in '{pdf_file_path}'")
        except Exception as e:
            print(f"Failed to convert page {page_number+1} in '{pdf_file_path}': {str(e)}")

# %%
df = pd.read_csv('scraped/statements.csv')
filtered_df = df[df.iloc[:, 2] > 0]



base_directory = 'TIFpdfs'
open_pdf_and_convert_to_image(filtered_df, base_directory)
# Out:
# Displayed 1997_001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13632\748717036.py in <module>
#       5
#       6 base_directory = 'TIFpdfs'
# ----> 7 open_pdf_and_convert_to_image(filtered_df, base_directory)
#
# ~\AppData\Local\Temp\ipykernel_13632\1082011269.py in open_pdf_and_convert_to_image(df, base_directory)
#      66                 cropped_image = image.crop((left, top, right, bottom))
#      67
# ---> 68                 cropped_image.show()
#      69                 print(f"Displayed {year}_{tif}")
#      70             else:
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in show(self, title)
#    2492         """
#    2493
# -> 2494         _show(self, title=title)
#    2495
#    2496     def split(self):
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _show(image, **options)
#    3537     from . import ImageShow
#    3538
# -> 3539     ImageShow.show(image, **options)
#    3540
#    3541
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show(image, title, **options)
#      60     """
#      61     for viewer in _viewers:
# ---> 62         if viewer.show(image, title=title, **options):
#      63             return True
#      64     return False
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show(self, image, **options)
#      84                 image = image.convert(base)
#      85
# ---> 86         return self.show_image(image, **options)
#      87
#      88     # hook methods
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show_image(self, image, **options)
#     111     def show_image(self, image, **options):
#     112         """Display the given image."""
# --> 113         return self.show_file(self.save_image(image), **options)
#     114
#     115     def show_file(self, path, **options):
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show_file(self, path, **options)
#     117         Display given file.
#     118         """
# --> 119         os.system(self.get_command(path, **options))  # nosec
#     120         return 1
#     121
#
# KeyboardInterrupt:
