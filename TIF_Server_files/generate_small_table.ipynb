# %%
import pandas as pd

# %%
# Read in the database
DATABASE_FILE = '../database.csv'
database = pd.read_csv(DATABASE_FILE)

# %%
database
# Out:
#          year  tif_number  page_num  block_num  par_num  line_num  word_num  \
# 0        2018           1         0          1        1         1         1
# 1        2018           1         0          1        1         1         2
# 2        2018           1         0          9        1         1         1
# 3        2018           1         0          9        1         1         2
# 4        2018           1         0          9        1         1         3
# ...       ...         ...       ...        ...      ...       ...       ...
# 3992290  2013          49        37         12        1         2         6
# 3992291  2013          49        37         12        1         2         7
# 3992292  2013          49        37         12        1         2         8
# 3992293  2013          49        37         13        1         1         1
# 3992294  2013          49        37         13        1         2         2
#
#          left   top  width  height   conf           text
# ...

# %%
# Get 1997
document_words = database[(database['year']==2018)]


# Get first 5 tifs
year_list = ['1','2','4','5','9']
document_words = document_words[(database['tif_number']==1) | (database['tif_number']==2) | (database['tif_number']==4) | (database['tif_number']==5) | (database['tif_number']==9)]
# Out:
# C:\Users\noahb\AppData\Local\Temp\ipykernel_2784\2369612045.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   document_words = document_words[(database['tif_number']==1) | (database['tif_number']==2) | (database['tif_number']==4) | (database['tif_number']==5) | (database['tif_number']==9)]

# %%
document_words
# Out:
#        year  tif_number  page_num  block_num  par_num  line_num  word_num  \
# 0      2018           1         0          1        1         1         1
# 1      2018           1         0          1        1         1         2
# 2      2018           1         0          9        1         1         1
# 3      2018           1         0          9        1         1         2
# 4      2018           1         0          9        1         1         3
# ...     ...         ...       ...        ...      ...       ...       ...
# 40407  2018           9        36          8        1         2         8
# 40408  2018           9        36          9        1         1         1
# 40409  2018           9        36         10        1         1         1
# 40410  2018           9        36         10        1         1         2
# 40411  2018           9        36         10        1         1         3
#
#        left   top  width  height   conf       text
# ...

# %%
document_words.to_csv('small_table.csv', index=False, header=False)
